# %%
a = 10 * 'string, '
a
# Out:
# 'string, string, string, string, string, string, string, string, string, string, '

# %%
test = 'algomania'
test.replace('mania', 'louco')
# Out:
# 'algolouco'

# %%
test.upper()
# Out:
# 'ALGOMANIA'

# %%
test.lower()
# Out:
# 'algomania'

# %%
test.title()
# Out:
# 'Algomania'

# %%
test.startswith('algo')
# Out:
# True

# %%
test.endswith('mania')
# Out:
# True

# %%
d = 'teste1, teste2, teste3'

d.split(', ')
# Out:
# ['teste1', 'teste2', 'teste3']

# %%
d = d.split(', ')
", ".join(d)
# Out:
# 'teste1, teste2, teste3'

# %%
spaced = '  teste  '

spaced.strip()
# Out:
# 'teste'

# %%
spaced.rstrip()
# Out:
# '  teste'

# %%
spaced.lstrip()
# Out:
# 'teste  '

# %%
s = '0123456789'

s[::-1]
# Out:
# '9876543210'
